# %% [markdown]
# https://www.geeksforgeeks.org/python/numpy-tutorial/

# %% [markdown]
# https://www.geeksforgeeks.org/python/python-lists-vs-numpy-arrays/
#
# https://www.geeksforgeeks.org/pandas/introduction-to-pandas-in-python/

# %% [markdown]
# https://www.geeksforgeeks.org/python/vectorization-in-python/
#
# https://www.geeksforgeeks.org/numpy/different-ways-to-create-numpy-arrays-in-python/

# %% [markdown]
# https://www.geeksforgeeks.org/data-science/what-is-a-vector-database/
#
# https://www.geeksforgeeks.org/artificial-intelligence/how-to-setup-and-use-a-vector-database/
#
# https://www.geeksforgeeks.org/artificial-intelligence/integrating-vector-databases-with-llms/
#
#
# https://www.geeksforgeeks.org/dbms/top-vector-databases/
