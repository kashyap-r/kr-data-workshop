# %% [markdown]
# ### Module #1 - Introduction to Python
# #### Datatypes and Variables

# %%
roll_no = 420 
height = 5.11
name = "Bond"
is_student = True

# Check datatype 
print (type(roll_no))
print (type(height))
print (type(name))
print (type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# list 
fruits = ["apple", "banana", "cheeku"]

print (fruits)
fruits.append("Mango")
fruits.append("Mango")
print (fruits)
fruits.remove("Mango")
print (fruits)
# Out:
# ['apple', 'banana', 'cheeku']
# ['apple', 'banana', 'cheeku', 'Mango', 'Mango']
# ['apple', 'banana', 'cheeku', 'Mango']

# %%
# set 
fruits = {"apple", "banana", "banana", "cheeku"}
print (fruits)
# Out:
# {'cheeku', 'banana', 'apple'}
